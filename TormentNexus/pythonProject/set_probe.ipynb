# %%
# Function to set Create Probe with given Geometry
def to_probeinterface(electrodes_df, **kwargs):
    import probeinterface as pi

    probe_df = electrodes_df.copy()
    probe_df.rename(
        columns={
            "electrode": "contact_ids",
            "shank": "shank_ids",
            "x_coord": "x",
            "y_coord": "y",
        },
        inplace=True,
    )
    # Get the contact shapes. By default, it's set to circle with a radius of 10.
    contact_shapes = kwargs.get("contact_shapes", "circle")
    assert (
        contact_shapes in pi.probe._possible_contact_shapes
    ), f"contacts shape should be in {pi.probe._possible_contact_shapes}"

    probe_df["contact_shapes"] = contact_shapes
    if contact_shapes == "circle":
        probe_df["radius"] = kwargs.get("radius", 10)
    elif contact_shapes == "square":
        probe_df["width"] = kwargs.get("width", 10)
    elif contact_shapes == "rect":
        probe_df["width"] = kwargs.get("width")
        probe_df["height"] = kwargs.get("height")

    return pi.Probe.from_dataframe(probe_df)

# %%
import pandas as pd
electrodes_df = pd.read_csv("probe_geometry.csv", usecols=["electrode", "x_coord", "y_coord", "shank", "channel_idx"])
electrodes_df
# Out:
#     electrode  x_coord  y_coord  shank  channel_idx
# 0           0      0.0      0.0      0           16
# 1           1      0.0    100.0      0           15
# 2           2      0.0    200.0      0           17
# 3           3      0.0    300.0      0           14
# 4           4      0.0    400.0      0           18
# 5           5      0.0    500.0      0           13
# 6           6      0.0    600.0      0           20
# 7           7      0.0    700.0      0           11
# 8           8      0.0    800.0      0           21
# 9           9      0.0    900.0      0           10
# 10         10      0.0   1000.0      0           22
# 11         11      0.0   1100.0      0            9
# 12         12      0.0   1200.0      0           31
# 13         13      0.0   1300.0      0            0
# 14         14      0.0   1400.0      0           30
# 15         15      0.0   1500.0      0            1
# 16         16      0.0   1600.0      0           29
# 17         17      0.0   1700.0      0            2
# 18         18      0.0   1800.0      0           27
# 19         19      0.0   1900.0      0            4
# 20         20      0.0   2000.0      0           26
# 21         21      0.0   2100.0      0            5
# 22         22      0.0   2200.0      0           25
# 23         23      0.0   2300.0      0            6
# 24         24      0.0   2400.0      0           24
# 25         25      0.0   2500.0      0            7
# 26         26      0.0   2600.0      0           28
# 27         27      0.0   2700.0      0            3
# 28         28      0.0   2800.0      0           23
# 29         29      0.0   2900.0      0            8
# 30         30      0.0   3000.0      0           19
# 31         31      0.0   3100.0      0           12

# %%
# Create SI probe object
si_probe = to_probeinterface(electrodes_df)
si_probe.set_device_channel_indices(electrodes_df["channel_idx"].values)

# %%
# Assign probe to recording (assume recording name is "si_recording")
# si_recording.set_probe(probe=si_probe, in_place=True)
